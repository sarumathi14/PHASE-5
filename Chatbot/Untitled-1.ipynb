# %%
import pandas as pd

# Create DataFrames
bot_data = pd.DataFrame([...]) # Use the data from above
user_data = pd.DataFrame([...]) # Use the data from above

# Save to Excel
with pd.ExcelWriter('bot_analytics_mock_data.xlsx') as writer:
    bot_data.to_excel(writer, sheet_name='bot_analytics', index=False)
    user_data.to_excel(writer, sheet_name='user_registration', index=False)
